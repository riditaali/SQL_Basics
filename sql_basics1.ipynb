# %%
df_1 = _deepnote_execute_sql('SELECT * \nFROM \'billionaires.csv\';', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_1
# Out:
#      rank  finalWorth               category                personName  age  \
# 0       1      211000       Fashion & Retail  Bernard Arnault & family   74
# 1       2      180000             Automotive                 Elon Musk   51
# 2       3      114000             Technology                Jeff Bezos   59
# 3       4      107000             Technology             Larry Ellison   78
# 4       5      106000  Finance & Investments            Warren Buffett   92
# ..    ...         ...                    ...                       ...  ...
# 470   497        5300                Service              Gary Rollins   78
# 471   497        5300  Finance & Investments               Mark Walter   62
# 472   497        5300          Manufacturing              Ronald Wanek   81
# 473   497        5300        Food & Beverage  Erich Wesjohann & family   77
# 474   497        5300       Fashion & Retail           M.A. Yusuff Ali   67
#
# ...

# %%
df_2 = _deepnote_execute_sql('-- not select everything in csv file\nSELECT personname, finalWorth\nFROM \'billionaires.csv\';', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_2
# Out:
#                    personName  finalWorth
# 0    Bernard Arnault & family      211000
# 1                   Elon Musk      180000
# 2                  Jeff Bezos      114000
# 3               Larry Ellison      107000
# 4              Warren Buffett      106000
# ..                        ...         ...
# 470              Gary Rollins        5300
# 471               Mark Walter        5300
# 472              Ronald Wanek        5300
# 473  Erich Wesjohann & family        5300
# 474           M.A. Yusuff Ali        5300
#
# [475 rows x 2 columns]

# %%
df_3 = _deepnote_execute_sql('-- select the countries but appearing only once\nSELECT DISTINCT country\nFROM \'billionaires.csv\';', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_3
# Out:
#                  country
# 0                 France
# 1          United States
# 2                 Mexico
# 3                  India
# 4                  Spain
# 5                  China
# 6                 Canada
# 7                Germany
# 8            Switzerland
# 9                Belgium
# 10               Austria
# 11                 Japan
# 12        United Kingdom
# 13             Australia
# 14             Indonesia
# 15  United Arab Emirates
# 16                Russia
# 17                 Chile
# 18        Czech Republic
# 19                Sweden
# 20              Thailand
# 21             Singapore
# 22               Nigeria
# 23                Israel
# 24                 Italy
# 25          South Africa
# 26                Brazil
# 27              Malaysia
# 28           South Korea
# 29           New Zealand
# 30           Philippines
# 31                Norway
# 32                 Egypt
# 33               Denmark
# 34              Colombia
# 35           Netherlands
# ...

# %%
df_4 = _deepnote_execute_sql('-- aggregate only distinct countries\nSELECT COUNT(DISTINCT country), COUNT(DISTINCT personname)\nFROM \'billionaires.csv\';', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_4
# Out:
#    count(DISTINCT country)  count(DISTINCT personname)
# 0                       39                         475

# %%
df_5 = _deepnote_execute_sql('-- average net worth\nSELECT AVG(finalWorth)\nFROM \'billionaires.csv\';', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_5
# Out:
#    avg(finalWorth)
# 0     14821.894737

# %%
df_6 = _deepnote_execute_sql('-- Filtering with WHERE Clause || One condition \nSELECT * FROM \'billionaires.csv\'\nWHERE country = \'France\'; -- case sensitive', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_6
# Out:
#     rank  finalWorth               category  \
# 0      1      211000       Fashion & Retail
# 1     11       80500       Fashion & Retail
# 2     28       40100       Fashion & Retail
# 3     71       22000        Food & Beverage
# 4    184        9800              Logistics
# 5    184        9800              Logistics
# 6    184        9800              Logistics
# 7    202        9500  Finance & Investments
# 8    256        8100            Diversified
# 9    256        8100            Diversified
# 10   256        8100            Diversified
# 11   282        7700        Food & Beverage
# 12   282        7700        Food & Beverage
# 13   365        6700                Telecom
# 14   397        6400                 Energy
# 15   405        6300             Healthcare
#
#                                personName  age country       city  \
# 0                Bernard Arnault & family   74  France      Paris
# 1   Francoise Bettencourt Meyers & family   69  France      Paris
# ...

# %%
df_7 = _deepnote_execute_sql('-- Filtering with WHERE Clause || Multiple conditions | comment the other lines of this block when running this portion\n--SELECT * FROM \'billionaires.csv\'\n--WHERE country = \'France\' AND city <> \'Paris\'; \n\n--another example | comment the other lines of this block when running this portion \n--SELECT * FROM \'billionaires.csv\'\n--WHERE country = \'France\' OR country = \'Spain\'; \n\n-- IN for multiple conditions\nSELECT * FROM \'billionaires.csv\'\nWHERE country IN (\'France\', \'Spain\', \'Italy\')', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_7
# Out:
#     rank  finalWorth               category  \
# 0      1      211000       Fashion & Retail
# 1     11       80500       Fashion & Retail
# 2     28       40100       Fashion & Retail
# 3     71       22000        Food & Beverage
# 4    184        9800              Logistics
# 5    184        9800              Logistics
# 6    184        9800              Logistics
# 7    202        9500  Finance & Investments
# 8    256        8100            Diversified
# 9    256        8100            Diversified
# 10   256        8100            Diversified
# 11   282        7700        Food & Beverage
# 12   282        7700        Food & Beverage
# 13   365        6700                Telecom
# 14   397        6400                 Energy
# 15   405        6300             Healthcare
# 16    13       77300       Fashion & Retail
# 17   344        6900       Fashion & Retail
# 18   157       11100       Fashion & Retail
# 19   352        6800            Diversified
# ...

# %%
df_8 = _deepnote_execute_sql('-- combine the functions from above \nSELECT COUNT(personname) FROM \'billionaires.csv\'\nWHERE selfmade = \'true\'', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_8
# Out:
#    count(personname)
# 0                309

# %%
df_9 = _deepnote_execute_sql('-- groupby statement\nSELECT industries, COUNT(personname) AS billionaire_count --header name change\nFROM \'billionaires.csv\'\nGROUP BY industries\nORDER BY COUNT(personname) DESC --to be in descending or ascending order\n--to limit the number for display\nLIMIT 10;', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_9
# Out:
#               industries  billionaire_count
# 0  Finance & Investments                 77
# 1             Technology                 62
# 2       Fashion & Retail                 54
# 3          Manufacturing                 44
# 4        Food & Beverage                 43
# 5            Diversified                 31
# 6                 Energy                 28
# 7             Healthcare                 27
# 8            Real Estate                 24
# 9        Metals & Mining                 20

# %%
df_10 = _deepnote_execute_sql('--Use BY\nSELECT birthmonth, COUNT(personname) FROM \'billionaires.csv\'\nGROUP BY birthmonth\nORDER BY COUNT(personname) DESC;', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_10
# Out:
#     birthMonth  count(personname)
# 0            1                 84
# 1            9                 47
# 2            3                 46
# 3           10                 43
# 4            8                 41
# 5            6                 39
# 6            7                 35
# 7            4                 31
# 8            2                 29
# 9            5                 29
# 10          12                 26
# 11          11                 25

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=a0ac54b7-9fc5-4506-a840-d0d87dd16e03' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
